# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 37s 0us/step

# %%
img_path = 'elephant.jpg'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\python\python37\lib\site-packages (from scikit-image) (1.21.6)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\python\python37\lib\site-packages (from scikit-image) (9.4.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 713.1 kB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 989.2 kB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in c:\python\python37\lib\site-packages (from scikit-image) (1.7.3)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.29.0-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 824.4 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\python\python37\lib\site-packages (from scikit-image) (23.0)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      -------------------------------------- 178.9/178.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.3.0 imageio-2.29.0 networkx-2.6.3 scikit-image-0.19.3 tifffile-2021.11.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from skimage.io import imread

# %%
img = imread(img_path)

# %%
plt.imshow(img)

# %%
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 204ms/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02504458', 'African_elephant', 0.7357572), ('n01871265', 'tusker', 0.15648705), ('n02504013', 'Indian_elephant', 0.106666565)]

# %%
image_path = 'pug.jpg'

# %%
new_img = imread(image_path)

# %%
plt.imshow(new_img)

# %%
img = image.load_img(image_path, target_size=(224, 224))
x = image.img_to_array(new_img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02110958', 'pug', 0.18792862), ('n02108422', 'bull_mastiff', 0.13401021), ('n02099712', 'Labrador_retriever', 0.05936612)]
